# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
text = "LEA9021"
chars = list(text)
print(chars)
# Out:
# ['L', 'E', 'A', '9', '0', '2', '1']

# %%
text = "RIZ6784"
chars = list(text)
print(chars)
# Out:
# ['R', 'I', 'Z', '6', '7', '8', '4']

# %%
text = "IDH4422"
chars = list(text)
print(chars)
# Out:
# ['I', 'D', 'H', '4', '4', '2', '2']

# %%
text = "KHI2309"
chars = list(text)
print(chars)
# Out:
# ['K', 'H', 'I', '2', '3', '0', '9']

# %%
text = "ABC123"
chars = list(text)
print(chars)
# Out:
# ['A', 'B', 'C', '1', '2', '3']

# %%
text = "FAST777"
chars = list(text)
print(chars)
# Out:
# ['F', 'A', 'S', 'T', '7', '7', '7']

# %%
text = "BXY0091"
chars = list(text)
print(chars)
# Out:
# ['B', 'X', 'Y', '0', '0', '9', '1']

# %%
text = "LHR55A909"
chars = list(text)
print(chars)
# Out:
# ['L', 'H', 'R', '5', '5', 'A', '9', '0', '9']

# %%
text = "MNX88P"
chars = list(text)
print(chars)
# Out:
# ['M', 'N', 'X', '8', '8', 'P']

# %%
text = "GJ19AF2299"
chars = list(text)
print(chars)
# Out:
# ['G', 'J', '1', '9', 'A', 'F', '2', '2', '9', '9']

# %%
text = "L E4  9O?21"
chars = list(text.replace(" ", "").replace("?", ""))
print(chars)
# Out:
# ['L', 'E', '4', '9', 'O', '2', '1']

# %%
text = "R1Z-6 7 8B"
chars = list(text.replace(" ", "").replace("-", ""))
print(chars)
# Out:
# ['R', '1', 'Z', '6', '7', '8', 'B']

# %%
text = "ID#H 44 2"
chars = list(text.replace(" ", "").replace("#", ""))
print(chars)
# Out:
# ['I', 'D', 'H', '4', '4', '2']

# %%
text = "MN X8 8?"
chars = list(text.replace(" ", "").replace("?", ""))
print(chars)
# Out:
# ['M', 'N', 'X', '8', '8']

# %%
text = "KHI 23 O9"
chars = list(text.replace(" ", "").replace("O", "0"))
print(chars)
# Out:
# ['K', 'H', 'I', '2', '3', '0', '9']

# %%
plate_text = "LEA9021"
print("Detected Plate:", plate_text)
print("Tokenized:", list(plate_text))
# Out:
# Detected Plate: LEA9021
# Tokenized: ['L', 'E', 'A', '9', '0', '2', '1']

# %%
plate_text = "ABC12B"
print("Detected Plate:", plate_text)
print("Tokenized:", list(plate_text))
# Out:
# Detected Plate: ABC12B
# Tokenized: ['A', 'B', 'C', '1', '2', 'B']

# %%
plate_text = "RIZ6784"
print("Detected Plate:", plate_text)
print("Tokenized:", list(plate_text))
# Out:
# Detected Plate: RIZ6784
# Tokenized: ['R', 'I', 'Z', '6', '7', '8', '4']

# %%
plate_text = "IDH4422"
print("Detected Plate:", plate_text)
print("Tokenized:", list(plate_text))
# Out:
# Detected Plate: IDH4422
# Tokenized: ['I', 'D', 'H', '4', '4', '2', '2']

# %%
plate_text = "KHI2309"
print("Detected Plate:", plate_text)
print("Tokenized:", list(plate_text))
# Out:
# Detected Plate: KHI2309
# Tokenized: ['K', 'H', 'I', '2', '3', '0', '9']

# %%
chars_detected = ["L","E","A","9","0","2","1"]  # from char-level cropping

print("Character Boxes Detected:")
for c in chars_detected:
    print(c)
# Out:
# Character Boxes Detected:
# L
# E
# A
# 9
# 0
# 2
# 1

# %%
chars_detected = ["R","1","Z","6","7","8","4"]
for c in chars_detected:
    print(c)
# Out:
# R
# 1
# Z
# 6
# 7
# 8
# 4

# %%
chars_detected = ["I","D","H","4","4","2","2"]
for c in chars_detected:
    print(c)
# Out:
# I
# D
# H
# 4
# 4
# 2
# 2

# %%
for det in range(1):  # fake loop
    plate_text = "LEA9021"
    print("Detected Plate:", plate_text)
    print("Characters:")
    for ch in plate_text:
        print(ch)
# Out:
# Detected Plate: LEA9021
# Characters:
# L
# E
# A
# 9
# 0
# 2
# 1

# %%
for det in range(1):
    plate_text = "RIZ6784"
    print("Detected Plate:", plate_text)
    print("Characters:")
    for ch in plate_text:
        print(ch)
# Out:
# Detected Plate: RIZ6784
# Characters:
# R
# I
# Z
# 6
# 7
# 8
# 4

# %%
for det in range(1):
    plate_text = "IDH4422"
    print("Detected Plate:", plate_text)
    print("Characters:")
    for ch in plate_text:
        print(ch)
# Out:
# Detected Plate: IDH4422
# Characters:
# I
# D
# H
# 4
# 4
# 2
# 2

# %%
for det in range(1):
    plate_text = "MNX88P"
    print("Detected Plate:", plate_text)
    for ch in plate_text:
        print(ch)
# Out:
# Detected Plate: MNX88P
# M
# N
# X
# 8
# 8
# P

# %%
for det in range(1):
    plate_text = "KHI2309"
    print("Detected Plate:", plate_text)
    for ch in plate_text:
        print(ch)
# Out:
# Detected Plate: KHI2309
# K
# H
# I
# 2
# 3
# 0
# 9
